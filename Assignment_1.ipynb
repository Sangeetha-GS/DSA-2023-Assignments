# %% [markdown]
# **Assignment on NumPy, Pandas, Matplotlib and Seaborn**

# %% [markdown]
# 1.  Reading the dataset to python environment

# %%
# importing all required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Reading the dataset

df = pd.read_excel("/content/iris.xls")

# %% [markdown]
#  2. Displaying Columns in dataset

# %%
# 2. Displaying Columns in dataset
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
column_names = df.columns
print(column_names)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3.  Calculate the mean of each column of the dataset.

# %%
# 3. Calculation mean of each

column_means = df.mean()
print(column_means)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-11-d1333a9605a2>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = df.mean()

# %%
df['SL'].mean() # calculating single column mean
# Out:
# 5.843333333333334

# %% [markdown]
# 4.  Check for the null values present in the dataset.

# %%
null_values = df.isnull()

# Count the number of null values in each column
null_counts = null_values.sum()

# Display the null counts
print(null_counts)
print(null_values )
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# 5 . Data Visualization

# %% [markdown]
#   a . Count Plot

# %%
sns.countplot(x='Classification', data=df)
# Out:
# <Axes: xlabel='Classification', ylabel='count'>

# %% [markdown]
# b. scatter plot

# %%
sns.scatterplot(x='SL',y='SW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %% [markdown]
# c . Displot

# %%
sns.distplot(df.PL)
# Out:
# <ipython-input-9-c121d1a2c449>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.PL)
# <Axes: xlabel='PL', ylabel='Density'>

# %% [markdown]
# d . KDE plot

# %%
sns.kdeplot(df.PW,color='g')
# Out:
# <Axes: xlabel='PW', ylabel='Density'>

# %% [markdown]
# e.violin plot

# %%
sns.violinplot(x = 'PL',y='Classification',data = df)
# Out:
# <Axes: xlabel='PL', ylabel='Classification'>

# %% [markdown]
# f. Box plot

# %%
sns.boxplot(x='SW',data=df,hue='Classification')
# Out:
# <Axes: xlabel='SW'>
